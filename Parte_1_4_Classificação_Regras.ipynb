# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus-henrique-lino/ciencia-de-dados/blob/main/Parte_1_4_Classificac%CC%A7a%CC%83o_Regras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Orange3
# Out:
# Collecting Orange3
#   Downloading orange3-3.40.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting AnyQt>=0.2.0 (from Orange3)
#   Downloading anyqt-0.2.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting baycomp>=1.0.2 (from Orange3)
#   Downloading baycomp-1.0.3.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: bottleneck>=1.3.4 in /usr/local/lib/python3.12/dist-packages (from Orange3) (1.4.2)
# Requirement already satisfied: chardet>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from Orange3) (5.2.0)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from Orange3) (0.28.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from Orange3) (1.5.3)
# Requirement already satisfied: keyring in /usr/local/lib/python3.12/dist-packages (from Orange3) (25.7.0)
# Collecting keyrings.alt (from Orange3)
#   Downloading keyrings.alt-5.0.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from Orange3) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from Orange3) (3.6.1)
# Requirement already satisfied: numpy<2.4,>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from Orange3) (2.0.2)
# Collecting openTSNE!=0.7.0,>=0.6.2 (from Orange3)
#   Downloading opentsne-1.0.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: openpyxl>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from Orange3) (3.1.5)
# Collecting orange-canvas-core<0.3a,>=0.2.5 (from Orange3)
#   Downloading orange_canvas_core-0.2.9-py3-none-any.whl.metadata (2.3 kB)
# Collecting orange-widget-base>=4.25.0 (from Orange3)
#   Downloading orange_widget_base-4.27.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from Orange3) (26.2)
# Requirement already satisfied: pandas<3,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from Orange3) (2.2.2)
# Requirement already satisfied: pygments>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from Orange3) (2.20.0)
# Collecting pyqtgraph>=0.13.1 (from Orange3)
#   Downloading pyqtgraph-0.14.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-louvain>=0.13 in /usr/local/lib/python3.12/dist-packages (from Orange3) (0.16)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from Orange3) (6.0.3)
# Collecting qtconsole>=4.7.2 (from Orange3)
#   Downloading qtconsole-5.7.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from Orange3) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from Orange3) (1.6.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.12/dist-packages (from Orange3) (1.16.3)
# Collecting serverfiles (from Orange3)
#   Downloading serverfiles-0.3.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xgboost>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from Orange3) (3.2.0)
# Requirement already satisfied: xlrd>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from Orange3) (2.0.2)
# Collecting xlsxwriter (from Orange3)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->Orange3) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->Orange3) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->Orange3) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->Orange3) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->Orange3) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.0->Orange3) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.3->Orange3) (2.0.0)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (0.21.2)
# Collecting commonmark>=0.8.1 (from orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading commonmark-0.9.2-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting requests-cache (from orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading requests_cache-1.3.2-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: pip>=18.0 in /usr/local/lib/python3.12/dist-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (24.1.2)
# Collecting dictdiffer (from orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting qasync>=0.10.0 (from orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading qasync-0.28.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (4.15.0)
# Collecting truststore (from orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading truststore-0.10.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.0.1->Orange3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.0.1->Orange3) (2026.2)
# Collecting colorama (from pyqtgraph>=0.13.1->Orange3)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: traitlets!=5.2.1,!=5.2.2 in /usr/local/lib/python3.12/dist-packages (from qtconsole>=4.7.2->Orange3) (5.7.1)
# Requirement already satisfied: jupyter_core in /usr/local/lib/python3.12/dist-packages (from qtconsole>=4.7.2->Orange3) (5.9.1)
# Requirement already satisfied: jupyter_client>=4.1 in /usr/local/lib/python3.12/dist-packages (from qtconsole>=4.7.2->Orange3) (7.4.9)
# Requirement already satisfied: ipykernel>=4.1 in /usr/local/lib/python3.12/dist-packages (from qtconsole>=4.7.2->Orange3) (6.17.1)
# Collecting ipython_pygments_lexers (from qtconsole>=4.7.2->Orange3)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting qtpy>=2.4.0 (from qtconsole>=4.7.2->Orange3)
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.1->Orange3) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost>=1.7.4->Orange3) (2.30.4)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring->Orange3) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring->Orange3) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring->Orange3) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring->Orange3) (4.5.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring->Orange3) (6.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->Orange3) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->Orange3) (2.5.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (6.5.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter_client>=4.1->qtconsole>=4.7.2->Orange3) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter_core->qtconsole>=4.7.2->Orange3) (4.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->Orange3) (1.17.0)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring->Orange3) (48.0.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring->Orange3) (10.8.0)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache->orange-canvas-core<0.3a,>=0.2.5->Orange3) (26.1.0)
# Collecting cattrs>=22.2 (from requests-cache->orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting url-normalize>=2.0 (from requests-cache->orange-canvas-core<0.3a,>=0.2.5->Orange3)
#   Downloading url_normalize-3.0.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring->Orange3) (2.0.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (4.9.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=2.0->SecretStorage>=3.2->keyring->Orange3) (3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.7.0)
# Downloading orange3-3.40.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 23.0 MB/s eta 0:00:00
# Downloading anyqt-0.2.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.2 MB/s eta 0:00:00
# Downloading opentsne-1.0.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 16.1 MB/s eta 0:00:00
# Downloading orange_canvas_core-0.2.9-py3-none-any.whl (537 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.0/538.0 kB 19.5 MB/s eta 0:00:00
# Downloading orange_widget_base-4.27.0-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 8.0 MB/s eta 0:00:00
# Downloading pyqtgraph-0.14.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.2 MB/s eta 0:00:00
# Downloading qtconsole-5.7.2-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 3.7 MB/s eta 0:00:00
# Downloading keyrings.alt-5.0.2-py3-none-any.whl (17 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 6.3 MB/s eta 0:00:00
# Downloading commonmark-0.9.2-py2.py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 1.4 MB/s eta 0:00:00
# Downloading qasync-0.28.0-py3-none-any.whl (16 kB)
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 2.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading requests_cache-1.3.2-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 3.4 MB/s eta 0:00:00
# Downloading truststore-0.10.4-py3-none-any.whl (18 kB)
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.5 MB/s eta 0:00:00
# Downloading url_normalize-3.0.0-py3-none-any.whl (16 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 28.7 MB/s eta 0:00:00
# Building wheels for collected packages: baycomp, serverfiles
#   Building wheel for baycomp (setup.py) ... done
#   Created wheel for baycomp: filename=baycomp-1.0.3-py3-none-any.whl size=18027 sha256=3e19ee9e7f091e58f3a4386ef8e28be36aab3d473441eaa6ef5ac81c0bc8b65b
#   Stored in directory: /root/.cache/pip/wheels/ff/39/6a/f87e05ad75b9d87f4eb262a897ec2fe3aab09449d13e3c3b2c
#   Building wheel for serverfiles (setup.py) ... done
#   Created wheel for serverfiles: filename=serverfiles-0.3.1-py3-none-any.whl size=6923 sha256=a0a1709164f4cea8fd7665f7c00d33a055afa3fe2930e72534b3359501979ff8
#   Stored in directory: /root/.cache/pip/wheels/48/b0/a2/a1adac874bb0c4a781f1d9d919d5435c1ba021570c5b0f470c
# Successfully built baycomp serverfiles
# Installing collected packages: dictdiffer, commonmark, xlsxwriter, url-normalize, truststore, qtpy, qasync, jedi, ipython_pygments_lexers, colorama, cattrs, AnyQt, serverfiles, requests-cache, pyqtgraph, keyrings.alt, orange-canvas-core, openTSNE, baycomp, qtconsole, orange-widget-base, Orange3
# Successfully installed AnyQt-0.2.1 Orange3-3.40.0 baycomp-1.0.3 cattrs-26.1.0 colorama-0.4.6 commonmark-0.9.2 dictdiffer-0.9.0 ipython_pygments_lexers-1.1.1 jedi-0.20.0 keyrings.alt-5.0.2 openTSNE-1.0.4 orange-canvas-core-0.2.9 orange-widget-base-4.27.0 pyqtgraph-0.14.0 qasync-0.28.0 qtconsole-5.7.2 qtpy-2.4.3 requests-cache-1.3.2 serverfiles-0.3.1 truststore-0.10.4 url-normalize-3.0.0 xlsxwriter-3.2.9

# %%
import Orange

# %% [markdown]
# ---
#
# Reconecte ao Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
DRIVE_DIRECTORY = "curso_ml"
DRIVE_DIRECTORY = os.path.join("/content/drive/MyDrive", DRIVE_DIRECTORY)

# %% [markdown]
# ---

# %%
import pickle

from collections import Counter

import pandas as pd
import seaborn as sns

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # Regras

# %% [markdown]
# Para gerar regras, nós precisamos começar com o arquivo com os dados originais, `cov_types.csv`, que deve estar salvo na sua pasta do Drive.
#
# Primeiro recarregue esse arquivo com o Pandas.

# %%
base = pd.read_csv('/content/drive/MyDrive/curso_ml/cov_types.csv')
base
# Out:
#       Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0        2767.0    66.0   17.0                             210.0
# 1        2724.0   160.0   19.0                              60.0
# 2        2360.0    65.0    7.0                             127.0
# 3        2995.0    45.0    4.0                             285.0
# 4        2400.0   106.0   27.0                             150.0
# ...         ...     ...    ...                               ...
# 9995     2917.0    90.0    9.0                             247.0
# 9996     3015.0    38.0    8.0                             361.0
# 9997     3052.0    79.0   19.0                              90.0
# 9998     2958.0    58.0    6.0                             319.0
# 9999     2682.0    91.0   13.0                             162.0
#
#       Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               18.0                           1190.0
# 1                                4.0                           1350.0
# 2                               21.0                           1377.0
# 3                               30.0                           5125.0
# 4                               63.0                            342.0
# ...                              ...                              ...
# 9995                            25.0                           4095.0
# 9996                            74.0                           4846.0
# 9997                            11.0                           1003.0
# 9998                            19.0                           2468.0
# 9999                            32.0                           1369.0
#
#       Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0             234.0           204.0           96.0
# 1             236.0           240.0          127.0
# 2             227.0           226.0          134.0
# 3             221.0           231.0          146.0
# 4             253.0           196.0           51.0
# ...             ...             ...            ...
# 9995          235.0           225.0          121.0
# 9996          220.0           223.0          138.0
# 9997          241.0           203.0           85.0
# 9998          225.0           227.0          137.0
# 9999          240.0           219.0          108.0
#
#       Horizontal_Distance_To_Fire_Points  Wilderness_Area  Soil_Type  \
# 0                                 2251.0                2         30
# 1                                 2514.0                2         16
# 2                                  339.0                3          5
# 3                                 5706.0                0         11
# 4                                  811.0                2          3
# ...                                  ...              ...        ...
# 9995                              3901.0                0         28
# 9996                              1611.0                0         28
# 9997                              1490.0                2         22
# 9998                              2280.0                0         28
# 9999                              1661.0                2         10
#
#           Cover_Type
# 0     Lodgepole Pine
# 1     Lodgepole Pine
# 2     Ponderosa Pine
# 3     Lodgepole Pine
# 4     Ponderosa Pine
# ...              ...
# 9995  Lodgepole Pine
# 9996  Lodgepole Pine
# 9997      Spruce/Fir
# 9998  Lodgepole Pine
# 9999  Lodgepole Pine
#
# [10000 rows x 13 columns]

# %% [markdown]
# Agora, lembre-se que a coluna com a classe deve ser indicada pelo prefixo `c#`. Então, vamos renomear a coluna `Cover_Type` para ficar neste formato.

# %%
base.rename(columns={"Cover_Type": "c#Cover_Type"}, inplace=True)
base
# Out:
#       Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0        2767.0    66.0   17.0                             210.0
# 1        2724.0   160.0   19.0                              60.0
# 2        2360.0    65.0    7.0                             127.0
# 3        2995.0    45.0    4.0                             285.0
# 4        2400.0   106.0   27.0                             150.0
# ...         ...     ...    ...                               ...
# 9995     2917.0    90.0    9.0                             247.0
# 9996     3015.0    38.0    8.0                             361.0
# 9997     3052.0    79.0   19.0                              90.0
# 9998     2958.0    58.0    6.0                             319.0
# 9999     2682.0    91.0   13.0                             162.0
#
#       Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               18.0                           1190.0
# 1                                4.0                           1350.0
# 2                               21.0                           1377.0
# 3                               30.0                           5125.0
# 4                               63.0                            342.0
# ...                              ...                              ...
# 9995                            25.0                           4095.0
# 9996                            74.0                           4846.0
# 9997                            11.0                           1003.0
# 9998                            19.0                           2468.0
# 9999                            32.0                           1369.0
#
#       Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0             234.0           204.0           96.0
# 1             236.0           240.0          127.0
# 2             227.0           226.0          134.0
# 3             221.0           231.0          146.0
# 4             253.0           196.0           51.0
# ...             ...             ...            ...
# 9995          235.0           225.0          121.0
# 9996          220.0           223.0          138.0
# 9997          241.0           203.0           85.0
# 9998          225.0           227.0          137.0
# 9999          240.0           219.0          108.0
#
#       Horizontal_Distance_To_Fire_Points  Wilderness_Area  Soil_Type  \
# 0                                 2251.0                2         30
# 1                                 2514.0                2         16
# 2                                  339.0                3          5
# 3                                 5706.0                0         11
# 4                                  811.0                2          3
# ...                                  ...              ...        ...
# 9995                              3901.0                0         28
# 9996                              1611.0                0         28
# 9997                              1490.0                2         22
# 9998                              2280.0                0         28
# 9999                              1661.0                2         10
#
#         c#Cover_Type
# 0     Lodgepole Pine
# 1     Lodgepole Pine
# 2     Ponderosa Pine
# 3     Lodgepole Pine
# 4     Ponderosa Pine
# ...              ...
# 9995  Lodgepole Pine
# 9996  Lodgepole Pine
# 9997      Spruce/Fir
# 9998  Lodgepole Pine
# 9999  Lodgepole Pine
#
# [10000 rows x 13 columns]

# %% [markdown]
# Salve o arquivo modificado. Como você só vai utilizar este arquivo neste exercício, não precisa salvar no Drive.

# %%
base.to_csv('cov_types.csv', index=False)

# %% [markdown]
# Gere uma instância da classe `Orange.data.Table` informando o arquivo `csv` contendo os dados.

# %%
base = Orange.data.Table('cov_types.csv')

# %% [markdown]
# Exiba o domínio desta base.

# %%
base.domain
# Out:
# [Elevation, Aspect, Slope, Horizontal_Distance_To_Hydrology, Vertical_Distance_To_Hydrology, Horizontal_Distance_To_Roadways, Hillshade_9am, Hillshade_Noon, Hillshade_3pm, Horizontal_Distance_To_Fire_Points, Wilderness_Area, Soil_Type | Cover_Type]

# %% [markdown]
# Utilize o método adequado da biblioteca Orange para separar 25% dos dados da base em um split de teste, e o restante em um split de treinamento. Você pode salvar o resultado da função diretamente nas variáveis dos splits correspondentes, observando que o split de teste é retornado primeiro.

# %%
base_test, base_train = Orange.evaluation.testing.sample(base, n=0.25)

# %% [markdown]
# Verifique o tamanho desses splits.

# %%
len(base_train), len(base_test)
# Out:
# (7500, 2500)

# %% [markdown]
# Instancie e ajuste um classificador do tipo `CN2Learner`.

# %%
cn2_classifier = Orange.classification.rules.CN2Learner()
rules = cn2_classifier(base_train)

# %% [markdown]
# Observe que, como esta base é maior, o número de regras é bastante elevado:

# %%
len(rules.rule_list)
# Out:
# 1614

# %% [markdown]
# Então, vamos visualizar somente as 10 primeiras regras:

# %%
for i, rule in enumerate(rules.rule_list):
    print(rule)
    if i == 10:
        break
# Out:
# IF Elevation>=3694.0 THEN Cover_Type=Krummholz
# IF Horizontal_Distance_To_Roadways>=6470.0 THEN Cover_Type=Lodgepole Pine
# IF Horizontal_Distance_To_Fire_Points>=4149.0 AND Wilderness_Area>=2.0 THEN Cover_Type=Krummholz
# IF Elevation>=3362.0 AND Elevation>=3624.0 THEN Cover_Type=Spruce/Fir
# IF Soil_Type>=34.0 AND Horizontal_Distance_To_Hydrology>=1060.0 THEN Cover_Type=Krummholz
# IF Elevation>=3325.0 AND Slope>=35.0 THEN Cover_Type=Krummholz
# IF Elevation>=3354.0 AND Horizontal_Distance_To_Roadways>=5292.0 THEN Cover_Type=Spruce/Fir
# IF Elevation>=3058.0 AND Horizontal_Distance_To_Fire_Points>=4981.0 THEN Cover_Type=Spruce/Fir
# IF Horizontal_Distance_To_Fire_Points>=4149.0 AND Hillshade_9am>=254.0 THEN Cover_Type=Aspen
# IF Elevation>=3302.0 AND Horizontal_Distance_To_Roadways>=5364.0 THEN Cover_Type=Spruce/Fir
# IF Soil_Type>=34.0 AND Horizontal_Distance_To_Roadways>=5525.0 THEN Cover_Type=Spruce/Fir

# %% [markdown]
# Faça predições informando ao algoritmo a base de teste.

# %%
y_pred = rules(base_test)
y_pred
# Out:
# array([4, 4, 6, ..., 4, 4, 4])

# %% [markdown]
# Observe que nós podemos recuperar os valores reais através do atributo `Y` de `base_test`.

# %%
y_test = base_test.Y
y_test
# Out:
# array([4., 4., 6., ..., 6., 4., 4.])

# %% [markdown]
# Utilize este valor para calcular a acurácia do modelo.

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6564

# %% [markdown]
# Desta vez você deve utilizar a função `confusion_matrix` do `sklearn` para exibir a matriz de confusão no formato de um array. Esta função recebe primeiro os valores reais, depois os valores preditos.

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[  7,   0,   0,   0,  18,   0,   8],
#        [  0,   3,   4,   0,   1,   8,   0],
#        [  1,   2,  21,   0,   7,  23,   6],
#        [  0,   0,   0,  42,   4,   0,  29],
#        [ 23,   0,  18,   8, 871,  19, 282],
#        [  7,   3,  28,   0,  13,  95,   2],
#        [  4,   0,   4,  29, 308,   0, 602]])

# %% [markdown]
# Você pode gerar um gráfico da matriz de confusão similar ao do yellowbrick com a função `sns.heatmap`:

# %%
sns.heatmap(cm,
            annot=True, # para exibir as contagens nas células do gráfico
            fmt='d', # para que os valores sejam em formato inteiro
            cmap='YlOrRd', # o mesmo mapa de cor do yellowbrick
            mask = (cm == 0) # não exibe os valores e a cor onde o valor for igual a 0
            );

# %% [markdown]
# Exiba o reporte de classificação do modelo.

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.21      0.19        33
#          1.0       0.38      0.19      0.25        16
#          2.0       0.28      0.35      0.31        60
#          3.0       0.53      0.56      0.55        75
#          4.0       0.71      0.71      0.71      1221
#          5.0       0.66      0.64      0.65       148
#          6.0       0.65      0.64      0.64       947
#
#     accuracy                           0.66      2500
#    macro avg       0.48      0.47      0.47      2500
# weighted avg       0.66      0.66      0.66      2500

# %% [markdown]
# ## Classificador base (majority learner)

# %% [markdown]
# Implemente um classificador do tipo `MajorityLearner`.

# %%
majority = Orange.classification.MajorityLearner()

# %% [markdown]
# Faça predições para a base inteira com base nesse classificador.

# %%
y_test = Orange.evaluation.testing.TestOnTestData(base, base, [majority])
y_test

# %% [markdown]
# Exiba a acurácia deste classificador.

# %%
Orange.evaluation.CA(y_test)
# Out:
# array([0.4847])

# %% [markdown]
# Exiba o número de registros em cada classe na base inteira.

# %%
from Orange.data import instance
Counter(str(instance.get_class()) for instance in base)
# Out:
# Counter({'Lodgepole Pine': 4847,
#          'Ponderosa Pine': 581,
#          'Spruce/Fir': 3714,
#          'Aspen': 163,
#          'Douglas-fir': 278,
#          'Krummholz': 362,
#          'Cottonwood/Willow': 55})

# %% [markdown]
# Veja que a base tem 10 mil registros:

# %%
len(base)
# Out:
# 10000

# %% [markdown]
# Isso significa que a classe majoritária, *Lodgepole Pine*, representa $4847/10000=0.4847\%$ dos dados, ou seja, exatamente a acurácia alcançada pelo classificador base do tipo *majority learner*.
